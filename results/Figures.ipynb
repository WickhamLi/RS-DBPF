# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
dyn = "Poly"
prop = "Uni"
re = "mul"
gamma = 0.0

# %%
mse_rsFalse_nfFalse_Poly_Boot_mul = np.loadtxt('rsdpf_0.1/mse_rsFalse_nfFalse_Poly_Boot_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsFalse_nfFalse_Poly_Deter_mul = np.loadtxt('rsdpf_0.1/mse_rsFalse_nfFalse_Poly_Deter_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsFalse_nfFalse_Poly_Uni_mul = np.loadtxt('rsdpf_0.1/mse_rsFalse_nfFalse_Poly_Uni_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsTrue_nfFalse_Poly_Boot_mul = np.loadtxt('rsdpf_0.1/mse_rsTrue_nfFalse_Poly_Boot_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsTrue_nfFalse_Poly_Deter_mul = np.loadtxt('rsdpf_0.1/mse_rsTrue_nfFalse_Poly_Deter_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsTrue_nfFalse_Poly_Uni_mul = np.loadtxt('rsdpf_0.1/mse_rsTrue_nfFalse_Poly_Uni_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))

mse_Poly_Boot_mul = np.loadtxt('rspf_0.1/mse_Poly_Boot_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Poly_Deter_mul = np.loadtxt('rspf_0.1/mse_Poly_Deter_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Poly_Uni_mul = np.loadtxt('rspf_0.1/mse_Poly_Uni_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))

mse_Poly_gamma0_mul = np.loadtxt(f'mmpf_0.1/mse_Poly_gamma0.0_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Poly_gamma5_mul = np.loadtxt(f'mmpf_0.1/mse_Poly_gamma0.5_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Poly_gamma1_mul = np.loadtxt(f'mmpf_0.1/mse_Poly_gamma1.0_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))

# msecum_dpf = mse_dpf.cumsum(axis=1) 
# msecum_pf = mse_pf.cumsum(axis=1)
# print(msecum_pf.mean(axis=0)[-1])
# msecum_mmpf = mse_mmpf.cumsum(axis=1)
# print(msecum_mmpf.mean(axis=0)[-1])
# msecum_singdpf = mse_singdpf.cumsum(axis=1)

# mse_dpfmax = mse_dpf.max(axis=0)
# mse_pfmax = mse_pf.max(axis=0)
# mse_singdpfmax = mse_singdpf.max(axis=0)

# mse_dpfmin = mse_dpf.min(axis=0)
# mse_pfmin = mse_pf.min(axis=0)
# mse_singdpfmin = mse_singdpf.min(axis=0)

# %%
print(mse_Poly_gamma0_mul.mean(), mse_Poly_gamma0_mul.mean(axis=1).min(), mse_Poly_gamma0_mul.mean(axis=1).max())
print(mse_Poly_gamma5_mul.mean(), mse_Poly_gamma5_mul.mean(axis=1).min(), mse_Poly_gamma5_mul.mean(axis=1).max())
print(mse_Poly_gamma1_mul.mean(), mse_Poly_gamma1_mul.mean(axis=1).min(), mse_Poly_gamma1_mul.mean(axis=1).max())

print(mse_rsFalse_nfFalse_Poly_Boot_mul.mean(), mse_rsFalse_nfFalse_Poly_Boot_mul.mean(axis=1).min(), mse_rsFalse_nfFalse_Poly_Boot_mul.mean(axis=1).max())
print(mse_rsFalse_nfFalse_Poly_Deter_mul.mean(), mse_rsFalse_nfFalse_Poly_Deter_mul.mean(axis=1).min(), mse_rsFalse_nfFalse_Poly_Deter_mul.mean(axis=1).max())
print(mse_rsFalse_nfFalse_Poly_Uni_mul.mean(), mse_rsFalse_nfFalse_Poly_Uni_mul.mean(axis=1).min(), mse_rsFalse_nfFalse_Poly_Uni_mul.mean(axis=1).max())

print(mse_rsTrue_nfFalse_Poly_Boot_mul.mean(), mse_rsTrue_nfFalse_Poly_Boot_mul.mean(axis=1).min(), mse_rsTrue_nfFalse_Poly_Boot_mul.mean(axis=1).max())
print(mse_rsTrue_nfFalse_Poly_Deter_mul.mean(), mse_rsTrue_nfFalse_Poly_Deter_mul.mean(axis=1).min(), mse_rsTrue_nfFalse_Poly_Deter_mul.mean(axis=1).max())
print(mse_rsTrue_nfFalse_Poly_Uni_mul.mean(), mse_rsTrue_nfFalse_Poly_Uni_mul.mean(axis=1).min(), mse_rsTrue_nfFalse_Poly_Uni_mul.mean(axis=1).max())

print(mse_Poly_Boot_mul.mean(), mse_Poly_Boot_mul.mean(axis=1).min(), mse_Poly_Boot_mul.mean(axis=1).max())
print(mse_Poly_Deter_mul.mean(), mse_Poly_Deter_mul.mean(axis=1).min(), mse_Poly_Deter_mul.mean(axis=1).max())
print(mse_Poly_Uni_mul.mean(), mse_Poly_Uni_mul.mean(axis=1).min(), mse_Poly_Uni_mul.mean(axis=1).max())
# Out:
# 5.059279508968809 0.364158579942352 29.696196559599997
# 5.72496056629705 0.9262793090420002 34.68325649614601
# 9.101906447754239 1.4563214727239997 67.89117142313577
# 7.855163858126556 1.028233218848734 51.16970987301585
# 8.451471259331724 1.3995365112479998 69.923202599749
# 8.40235140351744 1.40387495614399 69.6928600151584
# 1.4045734043254159 0.203428658651 14.661526128015998
# 1.1346977751283938 0.22455800119760003 9.76820944934076
# 1.204248622947961 0.19096292171799997 8.3251141614
# 0.4122748338907964 0.07083564541019392 3.0150479350640005
# 0.41070986297921963 0.07106921522744 3.0199847123748005
# 0.4137539475752032 0.06735065274804 3.0920144466059996

# %%
m = mse_Poly_gamma0_mul.mean(axis=1)
n = mse_Poly_gamma5_mul.mean(axis=1)
o = mse_Poly_gamma1_mul.mean(axis=1)
m = m[m<100]
n = n[n<100]
o = o[o<100]
print(m.mean(), m.shape, n.mean(), n.shape, o.mean(), o.shape)

p = mse_rsFalse_nfFalse_Poly_Boot_mul.mean(axis=1)
q = mse_rsFalse_nfFalse_Poly_Deter_mul.mean(axis=1)
r = mse_rsFalse_nfFalse_Poly_Uni_mul.mean(axis=1)
p = p[p<100]
q = q[q<100]
r = r[r<100]
print(p.mean(), p.shape, q.mean(), q.shape, r.mean(), r.shape)

s = mse_rsTrue_nfFalse_Poly_Boot_mul.mean(axis=1)
t = mse_rsTrue_nfFalse_Poly_Deter_mul.mean(axis=1)
u = mse_rsTrue_nfFalse_Poly_Uni_mul.mean(axis=1)
s = s[s<100]
t = t[t<100]
u = u[u<100]
print(s.mean(), s.shape, t.mean(), t.shape, u.mean(), u.shape)

v = mse_Poly_Boot_mul.mean(axis=1)
w = mse_Poly_Deter_mul.mean(axis=1)
x = mse_Poly_Uni_mul.mean(axis=1)
print(v.mean(), v.shape, w.mean(), w.shape, x.mean(), x.shape)
# Out:
# 5.059279508968809 (500,) 5.7249605662970495 (500,) 9.101906447754239 (500,)
# 7.855163858126556 (500,) 8.451471259331724 (500,) 8.402351403517441 (500,)
# 1.4045734043254159 (500,) 1.1346977751283938 (500,) 1.204248622947961 (500,)
# 0.41227483389079633 (500,) 0.4107098629792196 (500,) 0.4137539475752031 (500,)

# %%
plt.plot(mse_Poly_gamma0_mul.mean(axis=0), label='MM-PFs($\gamma$=0.0)', linewidth=0.5, marker='1', mfc='none', markersize=7)
plt.plot(mse_Poly_gamma5_mul.mean(axis=0), label='MM-PFs($\gamma$=0.5)', linewidth=0.5, marker='2', mfc='none', markersize=7)
plt.plot(mse_Poly_gamma1_mul.mean(axis=0), label='MM-PFs($\gamma$=1.0)', linewidth=0.5, marker='3', mfc='none', markersize=7)

plt.plot(mse_rsFalse_nfFalse_Poly_Boot_mul.mean(axis=0), label='Sin-DPFs(Bootstrap)', linewidth=0.5, marker='d', mfc='none', markersize=5)
plt.plot(mse_rsFalse_nfFalse_Poly_Deter_mul.mean(axis=0), label='Sin-DPFs(Deterministic)', linewidth=0.5, marker='s', mfc='none', markersize=5)
plt.plot(mse_rsFalse_nfFalse_Poly_Uni_mul.mean(axis=0), label='Sin-DPFs(Uniform)', linewidth=0.5, marker='+', mfc='none', markersize=7)

plt.plot(mse_rsTrue_nfFalse_Poly_Boot_mul.mean(axis=0), label='RS-DPFs(Bootstrap)', linewidth=0.5, marker='^', mfc='none', markersize=6)
plt.plot(mse_rsTrue_nfFalse_Poly_Deter_mul.mean(axis=0), label='RS-DPFs(Deterministic)', linewidth=0.5, marker='v', mfc='none', markersize=6)
plt.plot(mse_rsTrue_nfFalse_Poly_Uni_mul.mean(axis=0), label='RS-DPFs(Uniform)', linewidth=0.5, marker='*', mfc='none', markersize=7)

plt.plot(mse_Poly_Boot_mul.mean(axis=0), label='RS-PFs(Bootstrap)', linewidth=0.5, marker='<', mfc='none', markersize=6)
plt.plot(mse_Poly_Deter_mul.mean(axis=0), label='RS-PFs(Deterministic)', linewidth=0.5, marker='>', mfc='none', markersize=6)
plt.plot(mse_Poly_Uni_mul.mean(axis=0), label='RS-PFs(Uniform)', linewidth=0.5, marker='.', mfc='none', markersize=6)

# plt.fill_between(np.arange(50), mse_dpfmax, mse_dpfmin, alpha=0.2)
# plt.fill_between(np.arange(50), mse_pfmax, mse_pfmin, alpha=0.2)
# plt.fill_between(np.arange(50), mse_singdpfmax, mse_singdpfmin, alpha=0.2)

plt.xlabel('Time Step (Polya urn dynamics)', fontsize=10)
plt.ylabel('Average MSE', fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.yscale('log')
plt.legend(bbox_to_anchor=(1.1, 1.3), fontsize=10, ncol=3)
# plt.tight_layout()
plt.savefig('MSE_Poly_1', bbox_inches='tight')
plt.show()

# %%
mse_rsFalse_nfFalse_Poly_Boot_mul = np.loadtxt('rsdpf_0.3/mse_rsFalse_nfFalse_Poly_Boot_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsFalse_nfFalse_Poly_Deter_mul = np.loadtxt('rsdpf_0.3/mse_rsFalse_nfFalse_Poly_Deter_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsFalse_nfFalse_Poly_Uni_mul = np.loadtxt('rsdpf_0.3/mse_rsFalse_nfFalse_Poly_Uni_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsTrue_nfFalse_Poly_Boot_mul = np.loadtxt('rsdpf_0.3/mse_rsTrue_nfFalse_Poly_Boot_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsTrue_nfFalse_Poly_Deter_mul = np.loadtxt('rsdpf_0.3/mse_rsTrue_nfFalse_Poly_Deter_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsTrue_nfFalse_Poly_Uni_mul = np.loadtxt('rsdpf_0.3/mse_rsTrue_nfFalse_Poly_Uni_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))

mse_Poly_Boot_mul = np.loadtxt('rspf_0.3/mse_Poly_Boot_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Poly_Deter_mul = np.loadtxt('rspf_0.3/mse_Poly_Deter_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Poly_Uni_mul = np.loadtxt('rspf_0.3/mse_Poly_Uni_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))

mse_Poly_gamma0_mul = np.loadtxt(f'mmpf_0.3/mse_Poly_gamma0.0_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Poly_gamma5_mul = np.loadtxt(f'mmpf_0.3/mse_Poly_gamma0.5_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Poly_gamma1_mul = np.loadtxt(f'mmpf_0.3/mse_Poly_gamma1.0_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))

# %%
print(mse_Poly_gamma0_mul.mean(), mse_Poly_gamma0_mul.mean(axis=1).min(), mse_Poly_gamma0_mul.mean(axis=1).max())
print(mse_Poly_gamma5_mul.mean(), mse_Poly_gamma5_mul.mean(axis=1).min(), mse_Poly_gamma5_mul.mean(axis=1).max())
print(mse_Poly_gamma1_mul.mean(), mse_Poly_gamma1_mul.mean(axis=1).min(), mse_Poly_gamma1_mul.mean(axis=1).max())

print(mse_rsFalse_nfFalse_Poly_Boot_mul.mean(), mse_rsFalse_nfFalse_Poly_Boot_mul.mean(axis=1).min(), mse_rsFalse_nfFalse_Poly_Boot_mul.mean(axis=1).max())
print(mse_rsFalse_nfFalse_Poly_Deter_mul.mean(), mse_rsFalse_nfFalse_Poly_Deter_mul.mean(axis=1).min(), mse_rsFalse_nfFalse_Poly_Deter_mul.mean(axis=1).max())
print(mse_rsFalse_nfFalse_Poly_Uni_mul.mean(), mse_rsFalse_nfFalse_Poly_Uni_mul.mean(axis=1).min(), mse_rsFalse_nfFalse_Poly_Uni_mul.mean(axis=1).max())

print(mse_rsTrue_nfFalse_Poly_Boot_mul.mean(), mse_rsTrue_nfFalse_Poly_Boot_mul.mean(axis=1).min(), mse_rsTrue_nfFalse_Poly_Boot_mul.mean(axis=1).max())
print(mse_rsTrue_nfFalse_Poly_Deter_mul.mean(), mse_rsTrue_nfFalse_Poly_Deter_mul.mean(axis=1).min(), mse_rsTrue_nfFalse_Poly_Deter_mul.mean(axis=1).max())
print(mse_rsTrue_nfFalse_Poly_Uni_mul.mean(), mse_rsTrue_nfFalse_Poly_Uni_mul.mean(axis=1).min(), mse_rsTrue_nfFalse_Poly_Uni_mul.mean(axis=1).max())

print(mse_Poly_Boot_mul.mean(), mse_Poly_Boot_mul.mean(axis=1).min(), mse_Poly_Boot_mul.mean(axis=1).max())
print(mse_Poly_Deter_mul.mean(), mse_Poly_Deter_mul.mean(axis=1).min(), mse_Poly_Deter_mul.mean(axis=1).max())
print(mse_Poly_Uni_mul.mean(), mse_Poly_Uni_mul.mean(axis=1).min(), mse_Poly_Uni_mul.mean(axis=1).max())
# Out:
# 4.788790706782524 0.9421647098939999 44.660397561197996
# 6.534609437833837 1.2269205491915998 39.02804691588
# 9.425491947099783 1.607277999976 68.62947342089599
# 7.0943244009718684 0.7470837543331998 63.29673106012
# 7.738340717659674 0.566230524588 86.29673421531997
# 7.661054397150561 0.49259656863551515 86.344325958732
# 2.0967443750530608 0.339008235785 31.1258253669
# 1.6458091511137696 0.3154509174652 14.85361468300288
# 1.7593377481299743 0.3983164456443999 24.109275662580004
# 1.271228078249802 0.25912172618059404 12.085837712224402
# 1.498296386312303 0.36784213043608993 16.40079213521
# 1.495430431762968 0.3612561431889201 16.3037346538268

# %%
plt.plot(mse_Poly_gamma0_mul.mean(axis=0), label='MM-PFs($\gamma$=0.0)', linewidth=0.5, marker='1', mfc='none', markersize=7)
plt.plot(mse_Poly_gamma5_mul.mean(axis=0), label='MM-PFs($\gamma$=0.5)', linewidth=0.5, marker='2', mfc='none', markersize=7)
plt.plot(mse_Poly_gamma1_mul.mean(axis=0), label='MM-PFs($\gamma$=1.0)', linewidth=0.5, marker='3', mfc='none', markersize=7)

plt.plot(mse_rsFalse_nfFalse_Poly_Boot_mul.mean(axis=0), label='Sin-DPFs(Bootstrap)', linewidth=0.5, marker='d', mfc='none', markersize=5)
plt.plot(mse_rsFalse_nfFalse_Poly_Deter_mul.mean(axis=0), label='Sin-DPFs(Deterministic)', linewidth=0.5, marker='s', mfc='none', markersize=5)
plt.plot(mse_rsFalse_nfFalse_Poly_Uni_mul.mean(axis=0), label='Sin-DPFs(Uniform)', linewidth=0.5, marker='+', mfc='none', markersize=7)

plt.plot(mse_rsTrue_nfFalse_Poly_Boot_mul.mean(axis=0), label='RS-DPFs(Bootstrap)', linewidth=0.5, marker='^', mfc='none', markersize=6)
plt.plot(mse_rsTrue_nfFalse_Poly_Deter_mul.mean(axis=0), label='RS-DPFs(Deterministic)', linewidth=0.5, marker='v', mfc='none', markersize=6)
plt.plot(mse_rsTrue_nfFalse_Poly_Uni_mul.mean(axis=0), label='RS-DPFs(Uniform)', linewidth=0.5, marker='*', mfc='none', markersize=7)

plt.plot(mse_Poly_Boot_mul.mean(axis=0), label='RS-PFs(Bootstrap)', linewidth=0.5, marker='<', mfc='none', markersize=6)
plt.plot(mse_Poly_Deter_mul.mean(axis=0), label='RS-PFs(Deterministic)', linewidth=0.5, marker='>', mfc='none', markersize=6)
plt.plot(mse_Poly_Uni_mul.mean(axis=0), label='RS-PFs(Uniform)', linewidth=0.5, marker='.', mfc='none', markersize=6)

# plt.fill_between(np.arange(50), mse_dpfmax, mse_dpfmin, alpha=0.2)
# plt.fill_between(np.arange(50), mse_pfmax, mse_pfmin, alpha=0.2)
# plt.fill_between(np.arange(50), mse_singdpfmax, mse_singdpfmin, alpha=0.2)

plt.xlabel('Time Step (Polya urn dynamics)', fontsize=10)
plt.ylabel('Average MSE', fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.yscale('log')
plt.legend(bbox_to_anchor=(0.08, 0.45), fontsize=10, ncol=2)
# plt.tight_layout()
plt.savefig('MSE_Poly_3', bbox_inches='tight')
plt.show()

# %%
mse_rsFalse_nfFalse_Poly_Boot_mul = np.loadtxt('rsdpf_0.5/mse_rsFalse_nfFalse_Poly_Boot_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsFalse_nfFalse_Poly_Deter_mul = np.loadtxt('rsdpf_0.5/mse_rsFalse_nfFalse_Poly_Deter_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsFalse_nfFalse_Poly_Uni_mul = np.loadtxt('rsdpf_0.5/mse_rsFalse_nfFalse_Poly_Uni_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsTrue_nfFalse_Poly_Boot_mul = np.loadtxt('rsdpf_0.5/mse_rsTrue_nfFalse_Poly_Boot_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsTrue_nfFalse_Poly_Deter_mul = np.loadtxt('rsdpf_0.5/mse_rsTrue_nfFalse_Poly_Deter_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsTrue_nfFalse_Poly_Uni_mul = np.loadtxt('rsdpf_0.5/mse_rsTrue_nfFalse_Poly_Uni_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))

mse_Poly_Boot_mul = np.loadtxt('rspf_0.5/mse_Poly_Boot_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Poly_Deter_mul = np.loadtxt('rspf_0.5/mse_Poly_Deter_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Poly_Uni_mul = np.loadtxt('rspf_0.5/mse_Poly_Uni_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))

mse_Poly_gamma0_mul = np.loadtxt(f'mmpf_0.5/mse_Poly_gamma0.0_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Poly_gamma5_mul = np.loadtxt(f'mmpf_0.5/mse_Poly_gamma0.5_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Poly_gamma1_mul = np.loadtxt(f'mmpf_0.5/mse_Poly_gamma1.0_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))

# %%
print(mse_Poly_gamma0_mul.mean(), mse_Poly_gamma0_mul.mean(axis=1).min(), mse_Poly_gamma0_mul.mean(axis=1).max())
print(mse_Poly_gamma5_mul.mean(), mse_Poly_gamma5_mul.mean(axis=1).min(), mse_Poly_gamma5_mul.mean(axis=1).max())
print(mse_Poly_gamma1_mul.mean(), mse_Poly_gamma1_mul.mean(axis=1).min(), mse_Poly_gamma1_mul.mean(axis=1).max())

print(mse_rsFalse_nfFalse_Poly_Boot_mul.mean(), mse_rsFalse_nfFalse_Poly_Boot_mul.mean(axis=1).min(), mse_rsFalse_nfFalse_Poly_Boot_mul.mean(axis=1).max())
print(mse_rsFalse_nfFalse_Poly_Deter_mul.mean(), mse_rsFalse_nfFalse_Poly_Deter_mul.mean(axis=1).min(), mse_rsFalse_nfFalse_Poly_Deter_mul.mean(axis=1).max())
print(mse_rsFalse_nfFalse_Poly_Uni_mul.mean(), mse_rsFalse_nfFalse_Poly_Uni_mul.mean(axis=1).min(), mse_rsFalse_nfFalse_Poly_Uni_mul.mean(axis=1).max())

print(mse_rsTrue_nfFalse_Poly_Boot_mul.mean(), mse_rsTrue_nfFalse_Poly_Boot_mul.mean(axis=1).min(), mse_rsTrue_nfFalse_Poly_Boot_mul.mean(axis=1).max())
print(mse_rsTrue_nfFalse_Poly_Deter_mul.mean(), mse_rsTrue_nfFalse_Poly_Deter_mul.mean(axis=1).min(), mse_rsTrue_nfFalse_Poly_Deter_mul.mean(axis=1).max())
print(mse_rsTrue_nfFalse_Poly_Uni_mul.mean(), mse_rsTrue_nfFalse_Poly_Uni_mul.mean(axis=1).min(), mse_rsTrue_nfFalse_Poly_Uni_mul.mean(axis=1).max())

print(mse_Poly_Boot_mul.mean(), mse_Poly_Boot_mul.mean(axis=1).min(), mse_Poly_Boot_mul.mean(axis=1).max())
print(mse_Poly_Deter_mul.mean(), mse_Poly_Deter_mul.mean(axis=1).min(), mse_Poly_Deter_mul.mean(axis=1).max())
print(mse_Poly_Uni_mul.mean(), mse_Poly_Uni_mul.mean(axis=1).min(), mse_Poly_Uni_mul.mean(axis=1).max())
# Out:
# 4.869060555433172 0.767094251317 28.638022263724007
# 6.76793213847794 1.780805484285596 34.4336789172
# 9.30786465709942 2.0588233486459004 57.975059796832
# 8.447209605891103 1.5458209084018 57.6904503125
# 8.521173538610576 1.6260360116660002 57.560989964685994
# 8.161828064621307 1.72238665963486 49.53821157387401
# 3.7492548550230005 0.8385875901112 31.977317653749154
# 2.255955320221486 0.7213816171702001 9.062616585611401
# 2.701114019774014 0.7338583898653203 9.7309772619
# 1.814073629662251 0.5398411176199999 5.569691260780001
# 2.4017233207535225 0.65840674479838 7.424495357744799
# 2.386688654373542 0.6087895541906 7.339872345440001

# %%
plt.plot(mse_Poly_gamma0_mul.mean(axis=0), label='MM-PFs($\gamma$=0.0)', linewidth=0.5, marker='1', mfc='none', markersize=7)
plt.plot(mse_Poly_gamma5_mul.mean(axis=0), label='MM-PFs($\gamma$=0.5)', linewidth=0.5, marker='2', mfc='none', markersize=7)
plt.plot(mse_Poly_gamma1_mul.mean(axis=0), label='MM-PFs($\gamma$=1.0)', linewidth=0.5, marker='3', mfc='none', markersize=7)

plt.plot(mse_rsFalse_nfFalse_Poly_Boot_mul.mean(axis=0), label='Sin-DPFs(Bootstrap)', linewidth=0.5, marker='d', mfc='none', markersize=5)
plt.plot(mse_rsFalse_nfFalse_Poly_Deter_mul.mean(axis=0), label='Sin-DPFs(Deterministic)', linewidth=0.5, marker='s', mfc='none', markersize=5)
plt.plot(mse_rsFalse_nfFalse_Poly_Uni_mul.mean(axis=0), label='Sin-DPFs(Uniform)', linewidth=0.5, marker='+', mfc='none', markersize=7)

plt.plot(mse_rsTrue_nfFalse_Poly_Boot_mul.mean(axis=0), label='RS-DPFs(Bootstrap)', linewidth=0.5, marker='^', mfc='none', markersize=6)
plt.plot(mse_rsTrue_nfFalse_Poly_Deter_mul.mean(axis=0), label='RS-DPFs(Deterministic)', linewidth=0.5, marker='v', mfc='none', markersize=6)
plt.plot(mse_rsTrue_nfFalse_Poly_Uni_mul.mean(axis=0), label='RS-DPFs(Uniform)', linewidth=0.5, marker='*', mfc='none', markersize=7)

plt.plot(mse_Poly_Boot_mul.mean(axis=0), label='RS-PFs(Bootstrap)', linewidth=0.5, marker='<', mfc='none', markersize=6)
plt.plot(mse_Poly_Deter_mul.mean(axis=0), label='RS-PFs(Deterministic)', linewidth=0.5, marker='>', mfc='none', markersize=6)
plt.plot(mse_Poly_Uni_mul.mean(axis=0), label='RS-PFs(Uniform)', linewidth=0.5, marker='.', mfc='none', markersize=6)

# plt.fill_between(np.arange(50), mse_dpfmax, mse_dpfmin, alpha=0.2)
# plt.fill_between(np.arange(50), mse_pfmax, mse_pfmin, alpha=0.2)
# plt.fill_between(np.arange(50), mse_singdpfmax, mse_singdpfmin, alpha=0.2)

plt.xlabel('Time Step (Polya urn dynamics)', fontsize=10)
plt.ylabel('Average MSE', fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.yscale('log')
plt.legend(bbox_to_anchor=(0.08, 0.45), fontsize=10, ncol=2)
# plt.tight_layout()
plt.savefig('MSE_Poly_5', bbox_inches='tight')
plt.show()

# %%
mse_rsFalse_nfFalse_Mark_Boot_mul = np.loadtxt('rsdpf_0.1/mse_rsFalse_nfFalse_Mark_Boot_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsFalse_nfFalse_Mark_Deter_mul = np.loadtxt('rsdpf_0.1/mse_rsFalse_nfFalse_Mark_Deter_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsFalse_nfFalse_Mark_Uni_mul = np.loadtxt('rsdpf_0.1/mse_rsFalse_nfFalse_Mark_Uni_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsTrue_nfFalse_Mark_Boot_mul= np.loadtxt('rsdpf_0.1/mse_rsTrue_nfFalse_Mark_Boot_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsTrue_nfFalse_Mark_Deter_mul = np.loadtxt('rsdpf_0.1/mse_rsTrue_nfFalse_Mark_Deter_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsTrue_nfFalse_Mark_Uni_mul= np.loadtxt('rsdpf_0.1/mse_rsTrue_nfFalse_Mark_Uni_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))


mse_Mark_Boot_mul = np.loadtxt('rspf_0.1/mse_Mark_Boot_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Mark_Deter_mul = np.loadtxt('rspf_0.1/mse_Mark_Deter_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Mark_Uni_mul = np.loadtxt('rspf_0.1/mse_Mark_Uni_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))

mse_Mark_gamma0_mul = np.loadtxt(f'mmpf_0.1/mse_Mark_gamma0.0_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Mark_gamma5_mul = np.loadtxt(f'mmpf_0.1/mse_Mark_gamma0.5_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Mark_gamma1_mul = np.loadtxt(f'mmpf_0.1/mse_Mark_gamma1.0_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))

# msecum_dpf = mse_dpf.cumsum(axis=1) 
# msecum_pf = mse_pf.cumsum(axis=1)
# msecum_singdpf = mse_singdpf.cumsum(axis=1)

# mse_dpfmax = mse_dpf.max(axis=0)
# mse_pfmax = mse_pf.max(axis=0)
# mse_singdpfmax = mse_singdpf.max(axis=0)

# mse_dpfmin = mse_dpf.min(axis=0)
# mse_pfmin = mse_pf.min(axis=0)
# mse_singdpfmin = mse_singdpf.min(axis=0)

# %%
print(mse_Mark_gamma0_mul.mean(), mse_Mark_gamma0_mul.mean(axis=1).min(), mse_Mark_gamma0_mul.mean(axis=1).max())
print(mse_Mark_gamma5_mul.mean(), mse_Mark_gamma5_mul.mean(axis=1).min(), mse_Mark_gamma5_mul.mean(axis=1).max())
print(mse_Mark_gamma1_mul.mean(), mse_Mark_gamma1_mul.mean(axis=1).min(), mse_Mark_gamma1_mul.mean(axis=1).max())

print(mse_rsFalse_nfFalse_Mark_Boot_mul.mean(), mse_rsFalse_nfFalse_Mark_Boot_mul.mean(axis=1).min(), mse_rsFalse_nfFalse_Mark_Boot_mul.mean(axis=1).max())
print(mse_rsFalse_nfFalse_Mark_Deter_mul.mean(), mse_rsFalse_nfFalse_Mark_Deter_mul.mean(axis=1).min(), mse_rsFalse_nfFalse_Mark_Deter_mul.mean(axis=1).max())
print(mse_rsFalse_nfFalse_Mark_Uni_mul.mean(), mse_rsFalse_nfFalse_Mark_Uni_mul.mean(axis=1).min(), mse_rsFalse_nfFalse_Mark_Uni_mul.mean(axis=1).max())

print(mse_rsTrue_nfFalse_Mark_Boot_mul.mean(), mse_rsTrue_nfFalse_Mark_Boot_mul.mean(axis=1).min(), mse_rsTrue_nfFalse_Mark_Boot_mul.mean(axis=1).max())
print(mse_rsTrue_nfFalse_Mark_Deter_mul.mean(), mse_rsTrue_nfFalse_Mark_Deter_mul.mean(axis=1).min(), mse_rsTrue_nfFalse_Mark_Deter_mul.mean(axis=1).max())
print(mse_rsTrue_nfFalse_Mark_Uni_mul.mean(), mse_rsTrue_nfFalse_Mark_Uni_mul.mean(axis=1).min(), mse_rsTrue_nfFalse_Mark_Uni_mul.mean(axis=1).max())

print(mse_Mark_Boot_mul.mean(), mse_Mark_Boot_mul.mean(axis=1).min(), mse_Mark_Boot_mul.mean(axis=1).max())
print(mse_Mark_Deter_mul.mean(), mse_Mark_Deter_mul.mean(axis=1).min(), mse_Mark_Deter_mul.mean(axis=1).max())
print(mse_Mark_Uni_mul.mean(), mse_Mark_Uni_mul.mean(axis=1).min(), mse_Mark_Uni_mul.mean(axis=1).max())
# Out:
# 4.32862962899903 0.31336736738598003 91.50423756122
# 4.702971522277798 0.2851362832884 87.86307816199202
# 34.10186933109509 0.29538918836365996 558.4053442338
# 36.84514035475197 0.48311018738583994 609.9913155413824
# 33.79699287696377 0.8827518312932 546.0422184262
# 25.484712838254637 0.47622906200674 321.3461651636
# 0.7379764916708639 0.10895635611852 9.0532330016894
# 1.246969976489103 0.1640369658934 19.9116424110371
# 0.9729002092843364 0.27491192368144 9.19856671158
# 0.26218433594201895 0.056244551978599996 5.4801081797614595
# 0.2608701255851929 0.0502487983822 5.3632049638648
# 0.2621129958091647 0.052024498569700005 5.3956832794044

# %%
a = mse_Mark_gamma0_mul.mean(axis=1)
b = mse_Mark_gamma5_mul.mean(axis=1)
c = mse_Mark_gamma1_mul.mean(axis=1)
a = a[a<100]
b = b[b<100]
c = c[c<100]
print(a.mean(), a.shape, b.mean(), b.shape, c.mean(), c.shape)

d = mse_rsFalse_nfFalse_Mark_Boot_mul.mean(axis=1)
e = mse_rsFalse_nfFalse_Mark_Deter_mul.mean(axis=1)
f = mse_rsFalse_nfFalse_Mark_Uni_mul.mean(axis=1)
d = d[d<100]
e = e[e<100]
f = f[f<100]
print(d.mean(), d.shape, e.mean(), e.shape, f.mean(), f.shape)

g = mse_rsTrue_nfFalse_Mark_Boot_mul.mean(axis=1)
h = mse_rsTrue_nfFalse_Mark_Deter_mul.mean(axis=1)
i = mse_rsTrue_nfFalse_Mark_Uni_mul.mean(axis=1)
g = g[g<100]
h = h[h<100]
i = i[i<100]
print(g.mean(), g.shape, h.mean(), h.shape, i.mean(), i.shape)

j = mse_Mark_Boot_mul.mean(axis=1)
k = mse_Mark_Deter_mul.mean(axis=1)
l = mse_Mark_Uni_mul.mean(axis=1)
j = j[j<100]
k = k[k<100]
l = l[l<100]
print(j.mean(), j.shape, k.mean(), k.shape, l.mean(), l.shape)
# Out:
# 4.32862962899903 (500,) 4.7029715222777995 (500,) 19.48148596785473 (459,)
# 19.223869297002835 (453,) 20.073229669170974 (464,) 18.268073566421577 (479,)
# 0.7379764916708639 (500,) 1.246969976489103 (500,) 0.9729002092843364 (500,)
# 0.262184335942019 (500,) 0.2608701255851929 (500,) 0.2621129958091647 (500,)

# %%
# plt.figure(figsize=(8, 6))

plt.plot(mse_Mark_gamma0_mul.mean(axis=0), label='MM-PFs($\gamma$=0.0)', linewidth=0.5, marker='1', mfc='none', markersize=7)
plt.plot(mse_Mark_gamma5_mul.mean(axis=0), label='MM-PFs($\gamma$=0.5)', linewidth=0.5, marker='2', mfc='none', markersize=7)
plt.plot(mse_Mark_gamma1_mul.mean(axis=0), label='MM-PFs($\gamma$=1.0)', linewidth=0.5, marker='3', mfc='none', markersize=7)

plt.plot(mse_rsFalse_nfFalse_Mark_Boot_mul.mean(axis=0), label='Sin-DPFs(Bootstrap)', linewidth=0.5, marker='d', mfc='none', markersize=5)
plt.plot(mse_rsFalse_nfFalse_Mark_Deter_mul.mean(axis=0), label='Sin-DPFs(Deterministic)', linewidth=0.5, marker='s', mfc='none', markersize=5)
plt.plot(mse_rsFalse_nfFalse_Mark_Uni_mul.mean(axis=0), label='Sin-DPFs(Uniform)', linewidth=0.5, marker='+', mfc='none', markersize=7)

plt.plot(mse_rsTrue_nfFalse_Mark_Boot_mul.mean(axis=0), label='RS-DPFs(Bootstrap)', linewidth=0.5, marker='^', mfc='none', markersize=6)
plt.plot(mse_rsTrue_nfFalse_Mark_Deter_mul.mean(axis=0), label='RS-DPFs(Deterministic)', linewidth=0.5, marker='v', mfc='none', markersize=6)
plt.plot(mse_rsTrue_nfFalse_Mark_Uni_mul.mean(axis=0), label='RS-DPFs(Uniform)', linewidth=0.5, marker='*', mfc='none', markersize=7)

plt.plot(mse_Mark_Boot_mul.mean(axis=0), label='RS-PFs(Bootstrap)', linewidth=0.5, marker='<', mfc='none', markersize=6)
plt.plot(mse_Mark_Deter_mul.mean(axis=0), label='RS-PFs(Deterministic)', linewidth=0.5, marker='>', mfc='none', markersize=6)
plt.plot(mse_Mark_Uni_mul.mean(axis=0), label='RS-PFs(Uniform)', linewidth=0.5, marker='.', mfc='none', markersize=6)

# plt.fill_between(np.arange(50), mse_dpfmax, mse_dpfmin, alpha=0.2)
# plt.fill_between(np.arange(50), mse_pfmax, mse_pfmin, alpha=0.2)
# plt.fill_between(np.arange(50), mse_singdpfmax, mse_singdpfmin, alpha=0.2)

plt.xlabel('Time Step (Markovian dynamics)', fontsize=10)
plt.ylabel('Average MSE', fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.yscale('log')
plt.legend(bbox_to_anchor=(1.1, 1.3), fontsize=10, ncol=3)
# plt.tight_layout()
plt.savefig('MSE_Mark_1', bbox_inches='tight')
plt.show()

# %%
mse_rsFalse_nfFalse_Mark_Boot_mul = np.loadtxt('rsdpf_0.3/mse_rsFalse_nfFalse_Mark_Boot_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsFalse_nfFalse_Mark_Deter_mul = np.loadtxt('rsdpf_0.3/mse_rsFalse_nfFalse_Mark_Deter_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsFalse_nfFalse_Mark_Uni_mul = np.loadtxt('rsdpf_0.3/mse_rsFalse_nfFalse_Mark_Uni_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsTrue_nfFalse_Mark_Boot_mul= np.loadtxt('rsdpf_0.3/mse_rsTrue_nfFalse_Mark_Boot_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsTrue_nfFalse_Mark_Deter_mul = np.loadtxt('rsdpf_0.3/mse_rsTrue_nfFalse_Mark_Deter_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsTrue_nfFalse_Mark_Uni_mul= np.loadtxt('rsdpf_0.3/mse_rsTrue_nfFalse_Mark_Uni_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))


mse_Mark_Boot_mul = np.loadtxt('rspf_0.3/mse_Mark_Boot_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Mark_Deter_mul = np.loadtxt('rspf_0.3/mse_Mark_Deter_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Mark_Uni_mul = np.loadtxt('rspf_0.3/mse_Mark_Uni_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))

mse_Mark_gamma0_mul = np.loadtxt(f'mmpf_0.3/mse_Mark_gamma0.0_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Mark_gamma5_mul = np.loadtxt(f'mmpf_0.3/mse_Mark_gamma0.5_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Mark_gamma1_mul = np.loadtxt(f'mmpf_0.3/mse_Mark_gamma1.0_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))

# %%
print(mse_Mark_gamma0_mul.mean(), mse_Mark_gamma0_mul.mean(axis=1).min(), mse_Mark_gamma0_mul.mean(axis=1).max())
print(mse_Mark_gamma5_mul.mean(), mse_Mark_gamma5_mul.mean(axis=1).min(), mse_Mark_gamma5_mul.mean(axis=1).max())
print(mse_Mark_gamma1_mul.mean(), mse_Mark_gamma1_mul.mean(axis=1).min(), mse_Mark_gamma1_mul.mean(axis=1).max())

print(mse_rsFalse_nfFalse_Mark_Boot_mul.mean(), mse_rsFalse_nfFalse_Mark_Boot_mul.mean(axis=1).min(), mse_rsFalse_nfFalse_Mark_Boot_mul.mean(axis=1).max())
print(mse_rsFalse_nfFalse_Mark_Deter_mul.mean(), mse_rsFalse_nfFalse_Mark_Deter_mul.mean(axis=1).min(), mse_rsFalse_nfFalse_Mark_Deter_mul.mean(axis=1).max())
print(mse_rsFalse_nfFalse_Mark_Uni_mul.mean(), mse_rsFalse_nfFalse_Mark_Uni_mul.mean(axis=1).min(), mse_rsFalse_nfFalse_Mark_Uni_mul.mean(axis=1).max())

print(mse_rsTrue_nfFalse_Mark_Boot_mul.mean(), mse_rsTrue_nfFalse_Mark_Boot_mul.mean(axis=1).min(), mse_rsTrue_nfFalse_Mark_Boot_mul.mean(axis=1).max())
print(mse_rsTrue_nfFalse_Mark_Deter_mul.mean(), mse_rsTrue_nfFalse_Mark_Deter_mul.mean(axis=1).min(), mse_rsTrue_nfFalse_Mark_Deter_mul.mean(axis=1).max())
print(mse_rsTrue_nfFalse_Mark_Uni_mul.mean(), mse_rsTrue_nfFalse_Mark_Uni_mul.mean(axis=1).min(), mse_rsTrue_nfFalse_Mark_Uni_mul.mean(axis=1).max())

print(mse_Mark_Boot_mul.mean(), mse_Mark_Boot_mul.mean(axis=1).min(), mse_Mark_Boot_mul.mean(axis=1).max())
print(mse_Mark_Deter_mul.mean(), mse_Mark_Deter_mul.mean(axis=1).min(), mse_Mark_Deter_mul.mean(axis=1).max())
print(mse_Mark_Uni_mul.mean(), mse_Mark_Uni_mul.mean(axis=1).min(), mse_Mark_Uni_mul.mean(axis=1).max())
# Out:
# 7.495577770730881 1.1620707085297999 117.78659533481999
# 5.6101649491968235 1.3535232333740002 47.88379122566
# 29.063370002831455 1.1114777455907998 340.97674381644
# 31.749098333732448 1.1498945977824802 657.7149409797622
# 31.212485859236814 1.1322919724299998 657.3877960504819
# 14.055548245413576 0.8088456501318 176.72103741519996
# 1.4690887259579015 0.39237509847780006 10.167929897727701
# 1.7497297732022714 0.47576785854614 9.82422969083068
# 2.5887076627414123 0.542170876097928 25.019800274458
# 0.7166715293443289 0.19293513786116598 9.72253180515996
# 1.0248633779040097 0.29363009109939997 11.04562986012128
# 1.0253573968271026 0.29880730872736 10.961306649504797

# %%
plt.plot(mse_Mark_gamma0_mul.mean(axis=0), label='MM-PFs($\gamma$=0.0)', linewidth=0.5, marker='1', mfc='none', markersize=7)
plt.plot(mse_Mark_gamma5_mul.mean(axis=0), label='MM-PFs($\gamma$=0.5)', linewidth=0.5, marker='2', mfc='none', markersize=7)
plt.plot(mse_Mark_gamma1_mul.mean(axis=0), label='MM-PFs($\gamma$=1.0)', linewidth=0.5, marker='3', mfc='none', markersize=7)

plt.plot(mse_rsFalse_nfFalse_Mark_Boot_mul.mean(axis=0), label='Sin-DPFs(Bootstrap)', linewidth=0.5, marker='d', mfc='none', markersize=5)
plt.plot(mse_rsFalse_nfFalse_Mark_Deter_mul.mean(axis=0), label='Sin-DPFs(Deterministic)', linewidth=0.5, marker='s', mfc='none', markersize=5)
plt.plot(mse_rsFalse_nfFalse_Mark_Uni_mul.mean(axis=0), label='Sin-DPFs(Uniform)', linewidth=0.5, marker='+', mfc='none', markersize=7)

plt.plot(mse_rsTrue_nfFalse_Mark_Boot_mul.mean(axis=0), label='RS-DPFs(Bootstrap)', linewidth=0.5, marker='^', mfc='none', markersize=6)
plt.plot(mse_rsTrue_nfFalse_Mark_Deter_mul.mean(axis=0), label='RS-DPFs(Deterministic)', linewidth=0.5, marker='v', mfc='none', markersize=6)
plt.plot(mse_rsTrue_nfFalse_Mark_Uni_mul.mean(axis=0), label='RS-DPFs(Uniform)', linewidth=0.5, marker='*', mfc='none', markersize=7)

plt.plot(mse_Mark_Boot_mul.mean(axis=0), label='RS-PFs(Bootstrap)', linewidth=0.5, marker='<', mfc='none', markersize=6)
plt.plot(mse_Mark_Deter_mul.mean(axis=0), label='RS-PFs(Deterministic)', linewidth=0.5, marker='>', mfc='none', markersize=6)
plt.plot(mse_Mark_Uni_mul.mean(axis=0), label='RS-PFs(Uniform)', linewidth=0.5, marker='.', mfc='none', markersize=6)

# plt.fill_between(np.arange(50), mse_dpfmax, mse_dpfmin, alpha=0.2)
# plt.fill_between(np.arange(50), mse_pfmax, mse_pfmin, alpha=0.2)
# plt.fill_between(np.arange(50), mse_singdpfmax, mse_singdpfmin, alpha=0.2)

plt.xlabel('Time Step (Markovian dynamics)', fontsize=10)
plt.ylabel('Average MSE', fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.yscale('log')
plt.legend(bbox_to_anchor=(0.08, 1), fontsize=10, ncol=2)
# plt.tight_layout()
plt.savefig('MSE_Mark_3', bbox_inches='tight')
plt.show()

# %%
mse_rsFalse_nfFalse_Mark_Boot_mul = np.loadtxt('rsdpf_0.5/mse_rsFalse_nfFalse_Mark_Boot_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsFalse_nfFalse_Mark_Deter_mul = np.loadtxt('rsdpf_0.5/mse_rsFalse_nfFalse_Mark_Deter_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsFalse_nfFalse_Mark_Uni_mul = np.loadtxt('rsdpf_0.5/mse_rsFalse_nfFalse_Mark_Uni_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsTrue_nfFalse_Mark_Boot_mul= np.loadtxt('rsdpf_0.5/mse_rsTrue_nfFalse_Mark_Boot_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsTrue_nfFalse_Mark_Deter_mul = np.loadtxt('rsdpf_0.5/mse_rsTrue_nfFalse_Mark_Deter_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_rsTrue_nfFalse_Mark_Uni_mul= np.loadtxt('rsdpf_0.5/mse_rsTrue_nfFalse_Mark_Uni_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))


mse_Mark_Boot_mul = np.loadtxt('rspf_0.5/mse_Mark_Boot_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Mark_Deter_mul = np.loadtxt('rspf_0.5/mse_Mark_Deter_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Mark_Uni_mul = np.loadtxt('rspf_0.5/mse_Mark_Uni_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))

mse_Mark_gamma0_mul = np.loadtxt(f'mmpf_0.5/mse_Mark_gamma0.0_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Mark_gamma5_mul = np.loadtxt(f'mmpf_0.5/mse_Mark_gamma0.5_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))
mse_Mark_gamma1_mul = np.loadtxt(f'mmpf_0.5/mse_Mark_gamma1.0_mul', delimiter=',', skiprows=1, usecols=(np.arange(1, 51)))

# %%
print(mse_Mark_gamma0_mul.mean(), mse_Mark_gamma0_mul.mean(axis=1).min(), mse_Mark_gamma0_mul.mean(axis=1).max())
print(mse_Mark_gamma5_mul.mean(), mse_Mark_gamma5_mul.mean(axis=1).min(), mse_Mark_gamma5_mul.mean(axis=1).max())
print(mse_Mark_gamma1_mul.mean(), mse_Mark_gamma1_mul.mean(axis=1).min(), mse_Mark_gamma1_mul.mean(axis=1).max())

print(mse_rsFalse_nfFalse_Mark_Boot_mul.mean(), mse_rsFalse_nfFalse_Mark_Boot_mul.mean(axis=1).min(), mse_rsFalse_nfFalse_Mark_Boot_mul.mean(axis=1).max())
print(mse_rsFalse_nfFalse_Mark_Deter_mul.mean(), mse_rsFalse_nfFalse_Mark_Deter_mul.mean(axis=1).min(), mse_rsFalse_nfFalse_Mark_Deter_mul.mean(axis=1).max())
print(mse_rsFalse_nfFalse_Mark_Uni_mul.mean(), mse_rsFalse_nfFalse_Mark_Uni_mul.mean(axis=1).min(), mse_rsFalse_nfFalse_Mark_Uni_mul.mean(axis=1).max())

print(mse_rsTrue_nfFalse_Mark_Boot_mul.mean(), mse_rsTrue_nfFalse_Mark_Boot_mul.mean(axis=1).min(), mse_rsTrue_nfFalse_Mark_Boot_mul.mean(axis=1).max())
print(mse_rsTrue_nfFalse_Mark_Deter_mul.mean(), mse_rsTrue_nfFalse_Mark_Deter_mul.mean(axis=1).min(), mse_rsTrue_nfFalse_Mark_Deter_mul.mean(axis=1).max())
print(mse_rsTrue_nfFalse_Mark_Uni_mul.mean(), mse_rsTrue_nfFalse_Mark_Uni_mul.mean(axis=1).min(), mse_rsTrue_nfFalse_Mark_Uni_mul.mean(axis=1).max())

print(mse_Mark_Boot_mul.mean(), mse_Mark_Boot_mul.mean(axis=1).min(), mse_Mark_Boot_mul.mean(axis=1).max())
print(mse_Mark_Deter_mul.mean(), mse_Mark_Deter_mul.mean(axis=1).min(), mse_Mark_Deter_mul.mean(axis=1).max())
print(mse_Mark_Uni_mul.mean(), mse_Mark_Uni_mul.mean(axis=1).min(), mse_Mark_Uni_mul.mean(axis=1).max())
# Out:
# 10.060142724574732 1.0111864983447998 122.475713716666
# 7.941476636839037 1.1510873190992 44.35819403186
# 27.353354672791696 1.87775251817494 534.4332130966392
# 31.255099021353974 1.6931195279420002 534.080779821008
# 21.402331728374985 1.375435735278 257.534540316432
# 26.383702068331715 2.45190351324 422.653463540226
# 2.330928725140085 0.774569273938 8.581536534802002
# 2.209097359481799 0.5112961375608599 6.948297113500599
# 2.2218378123594578 0.52594214106942 12.12755994650164
# 1.268569113156919 0.422791555221 6.6071598274286005
# 2.0415531658253214 0.45018141121620003 8.609447659448
# 2.0380844035858345 0.455250070698 8.535518094396

# %%
plt.plot(mse_Mark_gamma0_mul.mean(axis=0), label='MM-PFs($\gamma$=0.0)', linewidth=0.5, marker='1', mfc='none', markersize=7)
plt.plot(mse_Mark_gamma5_mul.mean(axis=0), label='MM-PFs($\gamma$=0.5)', linewidth=0.5, marker='2', mfc='none', markersize=7)
plt.plot(mse_Mark_gamma1_mul.mean(axis=0), label='MM-PFs($\gamma$=1.0)', linewidth=0.5, marker='3', mfc='none', markersize=7)

plt.plot(mse_rsFalse_nfFalse_Mark_Boot_mul.mean(axis=0), label='Sin-DPFs(Bootstrap)', linewidth=0.5, marker='d', mfc='none', markersize=5)
plt.plot(mse_rsFalse_nfFalse_Mark_Deter_mul.mean(axis=0), label='Sin-DPFs(Deterministic)', linewidth=0.5, marker='s', mfc='none', markersize=5)
plt.plot(mse_rsFalse_nfFalse_Mark_Uni_mul.mean(axis=0), label='Sin-DPFs(Uniform)', linewidth=0.5, marker='+', mfc='none', markersize=7)

plt.plot(mse_rsTrue_nfFalse_Mark_Boot_mul.mean(axis=0), label='RS-DPFs(Bootstrap)', linewidth=0.5, marker='^', mfc='none', markersize=6)
plt.plot(mse_rsTrue_nfFalse_Mark_Deter_mul.mean(axis=0), label='RS-DPFs(Deterministic)', linewidth=0.5, marker='v', mfc='none', markersize=6)
plt.plot(mse_rsTrue_nfFalse_Mark_Uni_mul.mean(axis=0), label='RS-DPFs(Uniform)', linewidth=0.5, marker='*', mfc='none', markersize=7)

plt.plot(mse_Mark_Boot_mul.mean(axis=0), label='RS-PFs(Bootstrap)', linewidth=0.5, marker='<', mfc='none', markersize=6)
plt.plot(mse_Mark_Deter_mul.mean(axis=0), label='RS-PFs(Deterministic)', linewidth=0.5, marker='>', mfc='none', markersize=6)
plt.plot(mse_Mark_Uni_mul.mean(axis=0), label='RS-PFs(Uniform)', linewidth=0.5, marker='.', mfc='none', markersize=6)

# plt.fill_between(np.arange(50), mse_dpfmax, mse_dpfmin, alpha=0.2)
# plt.fill_between(np.arange(50), mse_pfmax, mse_pfmin, alpha=0.2)
# plt.fill_between(np.arange(50), mse_singdpfmax, mse_singdpfmin, alpha=0.2)

plt.xlabel('Time Step (Markovian dynamics)', fontsize=10)
plt.ylabel('Average MSE', fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.yscale('log')
plt.legend(bbox_to_anchor=(0.08, 0.41), fontsize=10, ncol=2)
# plt.tight_layout()
plt.savefig('MSE_Mark_5', bbox_inches='tight')
plt.show()

# %%
loss = [6.24854878, 4.92120546, 3.69062454, 2.94525069, 2.51159305, 2.40325917,
 2.33846411, 2.28567985, 2.20899892, 2.05749633, 2.00905622, 1.95058009,
 1.89565316, 1.86196174, 1.81738472, 1.78029458, 1.75621613, 1.74998585,
 1.70519351, 1.6858053,  1.67121756, 1.63065797, 1.61858568, 1.60809626,
 1.56783512, 1.55261712, 1.54956522, 1.54194355, 1.52170009, 1.51337621,
 1.49981182, 1.48306071, 1.47146062, 1.48105765, 1.4542646,  1.45169537,
 1.45761248, 1.45498976, 1.43703299, 1.41882831]

loss_2 = [8.47528362, 8.37858009, 8.30447006, 8.27472591, 8.27558899, 8.28476048,
 8.29149532, 8.29197693, 8.29980087, 8.30336952, 8.31934357, 8.32109165,
 8.32017231, 8.32297993, 8.32576084, 8.33490849, 8.32952785, 8.33658409,
 8.33666992, 8.34389019, 8.34742451, 8.34450245, 8.35007858, 8.35513973,
 8.3597126,  8.3511734,  8.35510159, 8.35755348, 8.35933399, 8.35659409,
 8.36001015, 8.36347294, 8.3674078,  8.36532593, 8.3693552,  8.37219906,
 8.3773756,  8.37613297, 8.37537289, 8.38378334]


plt.plot(loss, label='RS-DPFs')
plt.plot(loss_2, label='Single-DPFs')
plt.xlabel('Epochs (Polya urn dynamics)', fontsize=14)
plt.ylabel('Loss Gradient Descent', fontsize=14)
plt.legend(fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tight_layout()
plt.savefig('Loss_Poly')
plt.show()

# %%
loss = [21.5930863,  11.30776837,  6.32173134,  4.47627753,  3.80705309,  3.43777794,
  3.32419488,  3.22716062,  3.21415344,  3.07554913,  3.04019536,  2.97672066,
  3.03719433,  2.96501994,  2.94534553,  2.9110072,   2.91555214,  2.95532102,
  2.88272976,  2.88016542,  2.86418591,  2.86517046,  2.8666828,   2.83945508,
  2.80423559,  2.81860889,  2.87999877,  2.82262081,  2.85656514,  2.83626751,
  2.82824545,  2.86603452,  2.8134367,   2.8286126,   2.82921075,  2.759659,
  2.79770571,  2.80984689,  2.78861244,  2.76586788]

loss_2 = [32.65325165, 31.77769661, 31.53306198, 30.33294678, 29.8546505,  29.78432083,
 29.80675316, 29.84518051, 29.88392258, 29.91314316, 29.94296074, 29.9721241,
 30.04853439, 30.0953083,  30.14265251, 30.24643517, 30.31963921, 30.48240089,
 30.54908562, 30.67387962, 30.90299416, 31.1073246,  31.09927177, 31.36429214,
 31.47032166, 31.49756813, 31.61116219, 31.64026451, 31.74303436, 31.72513771,
 31.81769943, 31.86067963, 31.84264755, 31.8806591,  31.86923981, 31.95622444,
 31.95667267, 31.95836067, 31.96674919, 31.98321724]
  
plt.plot(loss, label='RS-DPFs')
plt.plot(loss_2, label='Single-DPFs')
plt.xlabel('Epochs (Markovian dynamics)', fontsize=14)
plt.ylabel('Loss Gradient Descent', fontsize=14)
plt.legend(fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tight_layout()
plt.savefig('Loss_Mark')
plt.show()
